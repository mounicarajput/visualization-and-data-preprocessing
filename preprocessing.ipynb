# %%
# !nvcc -V
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2018 NVIDIA Corporation
# Built on Sat_Aug_25_21:08:01_CDT_2018
# Cuda compilation tools, release 10.0, V10.0.130

# %%
# !nvidia-smi
# Out:
# Sun Jan 12 13:36:00 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 440.44       Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   37C    P0    27W / 250W |      0MiB / 16280MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# ...

# %%
# !rm rapids-colab.sh
# Out:
# rm: cannot remove 'rapids-colab.sh': No such file or directory

# %%
# Install RAPIDS
# !wget -nc https://raw.githubusercontent.com/rapidsai/notebooks-contrib/890b04ed8687da6e3a100c81f449ff6f7b559956/utils/rapids-colab.sh
# !bash rapids-colab.sh

import sys, os

dist_package_index = sys.path.index("/usr/local/lib/python3.6/dist-packages")
sys.path = sys.path[:dist_package_index] + ["/usr/local/lib/python3.6/site-packages"] + sys.path[dist_package_index:]
sys.path
if os.path.exists('update_pyarrow.py'): ## This file only exists if you're using RAPIDS version 0.11 or higher
  exec(open("update_pyarrow.py").read(), globals())
# Out:
# --2020-01-12 13:36:25--  https://raw.githubusercontent.com/rapidsai/notebooks-contrib/890b04ed8687da6e3a100c81f449ff6f7b559956/utils/rapids-colab.sh
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5286 (5.2K) [text/plain]
# Saving to: ‘rapids-colab.sh’
#
# rapids-colab.sh     100%[===================>]   5.16K  --.-KB/s    in 0s
#
# 2020-01-12 13:36:30 (125 MB/s) - ‘rapids-colab.sh’ saved [5286/5286]
#
# PLEASE READ
# ********************************************************************************************************
# Colab v0.11+ Migration Notice:
#
# There has been a NECESSARY Colab script code change for VERSION 0.11+ that MAY REQUIRE an update how you install RAPIDS into Colab!
# ...

# %%
import cudf
import numpy as np
from sklearn.preprocessing import MinMaxScaler
#df=cudf.read_csv("/content/sample_data/california_housing_test.csv")
data_length = 1e6
df = cudf.DataFrame()
df['in1'] = np.arange(data_length, dtype=np.float64)
 
#config={"column":["latitude"]}
scaler = MinMaxScaler()
def minmax_scaler(df,out):
  fit_data=scaler.fit(df)
  out=fit_data.data_max_
  return out

# %%
df=df.apply_rows(minmax_scaler,
                   incols=['in1'],
                   outcols=dict(out=np.float64),
                   kwargs=())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-9947022465b7> in <module>()
#       2                    incols=['in1'],
#       3                    outcols=dict(out=np.float64),
# ----> 4                    kwargs=())
#
# /usr/local/lib/python3.6/site-packages/cudf/core/dataframe.py in apply_rows(self, func, incols, outcols, kwargs, pessimistic_nulls, cache_key)
#    2970             kwargs,
#    2971             pessimistic_nulls,
# -> 2972             cache_key=cache_key,
#    2973         )
#    2974
#
# /usr/local/lib/python3.6/site-packages/cudf/utils/applyutils.py in apply_rows(df, func, incols, outcols, kwargs, pessimistic_nulls, cache_key)
#      73     """
#      74     applyrows = ApplyRowsCompiler(
# ---> 75         func, incols, outcols, kwargs, pessimistic_nulls, cache_key=cache_key
#      76     )
#      77     return applyrows.run(df)
#
# ...

# %%
import cudf
from cudf import DataFrame
df=cudf.read_csv("/content/sample_data/california_housing_test.csv")
config={"column":["population"]}
def add(df,config):
  return df.add_column("new_column",config["column"])
add(df,config)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-86b353c51b90> in <module>()
#       5 def add(df,config):
#       6   return df.add_column("new_column",config["column"])
# ----> 7 add(df,config)
#
# <ipython-input-10-86b353c51b90> in add(df, config)
#       4 config={"column":["population"]}
#       5 def add(df,config):
# ----> 6   return df.add_column("new_column",config["column"])
#       7 add(df,config)
#
# /usr/local/lib/python3.6/site-packages/cudf/core/dataframe.py in add_column(self, name, data, forceindex)
#    1586             data = Series(data)
#    1587         self._cols[name] = self._prepare_series_for_add(
# -> 1588             data, forceindex=forceindex, name=name
#    1589         )
#    1590
#
# /usr/local/lib/python3.6/site-packages/cudf/core/dataframe.py in _prepare_series_for_add(self, col, forceindex, name)
# ...

# %%
DataFrame.apply_rows(add,)

# %%
# !apt install cuda
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-430
# Use 'apt autoremove' to remove it.
# The following additional packages will be installed:
#   cuda-10-2 cuda-command-line-tools-10-2 cuda-compiler-10-2 cuda-cudart-10-2
#   cuda-cudart-dev-10-2 cuda-cufft-10-2 cuda-cufft-dev-10-2 cuda-cuobjdump-10-2
#   cuda-cupti-10-2 cuda-cupti-dev-10-2 cuda-curand-10-2 cuda-curand-dev-10-2
#   cuda-cusolver-10-2 cuda-cusolver-dev-10-2 cuda-cusparse-10-2
#   cuda-cusparse-dev-10-2 cuda-demo-suite-10-2 cuda-documentation-10-2
#   cuda-driver-dev-10-2 cuda-gdb-10-2 cuda-libraries-10-2
#   cuda-libraries-dev-10-2 cuda-license-10-2 cuda-memcheck-10-2
#   cuda-misc-headers-10-2 cuda-npp-10-2 cuda-npp-dev-10-2 cuda-nsight-10-2
#   cuda-nsight-compute-10-2 cuda-nsight-systems-10-2 cuda-nvcc-10-2
# ...

# %%
df = cudf.DataFrame({'x': range(10),
                     'y': [0, 1] * 5})
df
# Out:
#    x  y
# 0  0  0
# 1  1  1
# 2  2  0
# 3  3  1
# 4  4  0
# 5  5  1
# 6  6  0
# 7  7  1
# 8  8  0
# 9  9  1

# %%
import cudf
from sklearn.preprocessing import MinMaxScaler
df=cudf.read_csv('/content/sample_data/mnist_test.csv')
scaler = MinMaxScaler()
def minmax(df):
  fit_data=scaler.fit(df)
  max_=fit_data.data_max_
  a=scaler.transform(df)
  return max_
minmax(df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-132-599e10141c2f> in <module>()
#       8   a=scaler.transform(df)
#       9   return max_
# ---> 10 minmax(df)
#
# <ipython-input-132-599e10141c2f> in minmax(df)
#       4 scaler = MinMaxScaler()
#       5 def minmax(df):
# ----> 6   fit_data=scaler.fit(df)
#       7   max_=fit_data.data_max_
#       8   a=scaler.transform(df)
#
# /usr/local/lib/python3.6/site-packages/sklearn/preprocessing/_data.py in fit(self, X, y)
#     337         # Reset internal state before fitting
#     338         self._reset()
# --> 339         return self.partial_fit(X, y)
#     340
#     341     def partial_fit(self, X, y=None):
#
# /usr/local/lib/python3.6/site-packages/sklearn/preprocessing/_data.py in partial_fit(self, X, y)
#     371         X = check_array(X,
#     372                         estimator=self, dtype=FLOAT_DTYPES,
# ...

# %%
import cudf
import cuml
from cuml import PCA
from cuml.decomposition import TruncatedSVD

import numpy as np
df=cudf.read_csv('/content/sample_data/california_housing_test.csv')
def pca(df,config=None):
    tsvd_float = TruncatedSVD(n_components = 2, 
                              algorithm = "jacobi",
                              n_iter = 20, tol = 1e-9)
    tsvd_fit=tsvd_float.fit(df)
    exp_var = tsvd_fit.explained_variance_ratio_
    trans_gdf_float = tsvd_fit.transform(df)

    return exp_var,trans_gdf_float
pca(df)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-20-7e08550889de> in <module>()
# ----> 1 import cudf
#       2 import cuml
#       3 from cuml import PCA
#       4 from cuml.decomposition import TruncatedSVD
#       5
#
# /usr/local/lib/python3.6/site-packages/cudf/__init__.py in <module>()
#      21 )
#      22 from cudf.core.reshape import concat, get_dummies, melt
# ---> 23 from cudf.io import (
#      24     from_dlpack,
#      25     read_avro,
#
# /usr/local/lib/python3.6/site-packages/cudf/io/__init__.py in <module>()
#       7 from cudf.io.hdf import read_hdf
#       8 from cudf.io.json import read_json
# ----> 9 from cudf.io.orc import read_orc, read_orc_metadata, to_orc
#      10 from cudf.io.parquet import read_parquet, read_parquet_metadata
#
# /usr/local/lib/python3.6/site-packages/cudf/io/orc.py in <module>()
#       4
# ...

# %%
import cudf
df=cudf.read_csv("/content/loan_data_test.csv")
config={"columns":["State"]}

def drop_columns(df,config):
  return df.drop(config['columns'], axis=1)
drop_columns(df,config)
# Out:
#         ID Amount.Requested  ... Inquiries.in.the.Last.6.Months Employment.Length
# 0    20093             5000  ...                              0          < 1 year
# 1    62445            18000  ...                              0         10+ years
# 2    65248             7200  ...                              0           6 years
# 3    81822             7200  ...                              0         10+ years
# 4    57923            22000  ...                              0           8 years
# ..     ...              ...  ...                            ...               ...
# 295  24675            12000  ...                              2           7 years
# 296  69456             5000  ...                              0         10+ years
# 297  97954             4375  ...                              2           6 years
# 298  36931            13600  ...                              0         10+ years
# ...

# %%
pip install nltk
# Out:
# ...
#      |████████████████████████████████| 1.5MB 6.8MB/s
# ...
#   Created wheel for nltk: filename=nltk-3.4.5-cp36-none-any.whl size=1449907 sha256=f32e31b9ea8529d856f079a8d03e076f5a51aa21cf1e2c0d13ab54f132b9e655
#   Stored in directory: /root/.cache/pip/wheels/96/86/f6/68ab24c23f207c0077381a5e3904b2815136b879538a24b483
# Successfully built nltk
# ...

# %%
import cudf
import nltk
import pandas as pd
df=pd.read_csv('/content/products.csv')
config={"columns":["name"]}
def word_tokenizer(df,config): 
  for cols in config["columns"]:
    df[cols]=nltk.word_tokenize(df[cols])
    return df
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-8a0343147fdd> in <module>()
# ----> 1 import cudf
#       2 import nltk
#       3 import pandas as pd
#       4 df=pd.read_csv('/content/products.csv')
#       5 config={"columns":["name"]}
#
# ModuleNotFoundError: No module named 'cudf'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
def tok(col_names):
  for cols in col_names:
    df[cols] = nltk.word_tokenize(df[cols])

# %%
import cudf
df=cudf.read_csv('/content/loan_data_test.csv')
config={"columns":["State"]}

# %%
import nvstrings
import nvtext

def n_grams(df, config):
  x_range = df.shape[0]
  for cols in config['columns']:
    temp_col = []
    for i in range(x_range):
      mem_string = nvstrings.to_device(df[cols][i])
      mem_ngrams = nvtext.ngrams(mem_string,N=2,sep='_')
      temp_col.append(mem_ngrams.to_host())
  return temp_col

# %%
import pandas as pd
import cudf
def hot(df,config):
  for col in config["columns"]:
    df[col]=df[col].one_hot_encoding(col, 'prefix', 'cats')
cols=hot(df,config)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-43-6e72a54efa27> in <module>()
#       4   for col in config["columns"]:
#       5     df[col]=df[col].one_hot_encoding(col, 'prefix', 'cats')
# ----> 6 cols=hot(df,config)
#
# <ipython-input-43-6e72a54efa27> in hot(df, config)
#       3 def hot(df,config):
#       4   for col in config["columns"]:
# ----> 5     df[col]=df[col].one_hot_encoding(col, 'prefix', 'cats')
#       6 cols=hot(df,config)
#
# TypeError: one_hot_encoding() takes from 2 to 3 positional arguments but 4 were given

# %%
import numpy as np 
import cudf
import pandas as pd
import sklearn.preprocessing
from sklearn.preprocessing import Binarizer
df=pd.read_csv("/content/loan_data_test.csv")
config={"columns":["Amount.Requested","Amount.Funded.By.Investors"]}
def binarizer(df,config):
  for col in config["columns"]:
    df[col]=df[col].Binarizer(5000).fit_transform(df[col])

# %%
s3=df.add_strings(col)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-87-6faedaee73d2> in <module>()
# ----> 1 s3=df.add_strings(col)
#
# /usr/local/lib/python3.6/site-packages/cudf/core/dataframe.py in __getattr__(self, key)
#     334             return self[key]
#     335
# --> 336         raise AttributeError("'DataFrame' object has no attribute %r" % key)
#     337
#     338     def __getitem__(self, arg):
#
# AttributeError: 'DataFrame' object has no attribute 'add_strings'

# %%
df.add_string(col)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-81-a73494b1d9a0> in <module>()
# ----> 1 df.add_string(col)
#
# /usr/local/lib/python3.6/site-packages/cudf/core/dataframe.py in __getattr__(self, key)
#     334             return self[key]
#     335
# --> 336         raise AttributeError("'DataFrame' object has no attribute %r" % key)
#     337
#     338     def __getitem__(self, arg):
#
# AttributeError: 'DataFrame' object has no attribute 'add_string'

# %%
import numpy as np
df.apply_rows(tok,incols=["name"],outcols=dict(out1),kwargs=dict(kwarg1=3, kwarg2=4))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-59-c01fcb062387> in <module>()
#       1 import numpy as np
# ----> 2 df.apply_rows(tok,incols=["name"],outcols=dict(out1),kwargs=dict(kwarg1=3, kwarg2=4))
#
# NameError: name 'out1' is not defined

# %%
df.apply_rows(word_tokenizer)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-48-e6c3e5bc5507> in <module>()
# ----> 1 df.apply_rows(word_tokenizer)
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'apply_rows'

# %%
df=pd.read_csv('/content/products.csv')
df.head()
# Out:
#               SKU  ... restockingLeadTime
# 0  GGOEGDHQ014899  ...                  2
# 1  GGOEGOAB022499  ...                  2
# 2  GGOEYHPB072210  ...                  2
# 3  GGOEGEVB071799  ...                  2
# 4  GGOEYOLR018699  ...                  2
#
# [5 rows x 5 columns]

# %%
config["columns"]
# Out:
# ['name']

# %%
import cudf
import nltk
import pandas as pd

df=pd.read_csv('/content/products.csv')
config={"columns":"name"}
def word_tokenizer(df,config):
  for cols in config["columns"]:
      df=nltk.word_tokenize(df[config["columns"]])
      return df
word_tokenizer(df,config)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-40-51e8b026779f> in <module>()
#       9       df=nltk.word_tokenize(df[config["columns"]])
#      10       return df
# ---> 11 word_tokenizer(df,config)
#
# <ipython-input-40-51e8b026779f> in word_tokenizer(df, config)
#       7 def word_tokenizer(df,config):
#       8   for cols in config["columns"]:
# ----> 9       df=nltk.word_tokenize(df[config["columns"]])
#      10       return df
#      11 word_tokenizer(df,config)
#
# /usr/local/lib/python3.6/site-packages/nltk/tokenize/__init__.py in word_tokenize(text, language, preserve_line)
#     142     :type preserve_line: bool
#     143     """
# --> 144     sentences = [text] if preserve_line else sent_tokenize(text, language)
#     145     return [
#     146         token for sent in sentences for token in _treebank_word_tokenizer.tokenize(sent)
#
# ...

# %%
# !pip install query
# Out:
# ...
#      |████████████████████████████████| 389kB 4.8MB/s
# ...
#      |████████████████████████████████| 6.0MB 35.3MB/s
# ...
#   Created wheel for query: filename=query-0.1.4-cp36-none-any.whl size=387993 sha256=84516ca907d084486c8d67d8247bcd1e6fdb4ebfb05e3c47c97fad335da21d14
#   Stored in directory: /root/.cache/pip/wheels/90/f7/48/ec33fa3bd107c884b665f7f93807827f9b8fd78f27ac4c8e3d
# ...
#   Created wheel for sqlalchemy: filename=SQLAlchemy-1.3.12-cp36-cp36m-linux_x86_64.whl size=1215309 sha256=3ab8eb0b4f7b0431e109f12e28143acc0250d2112a1ac81e12aa753a960c5cff
#   Stored in directory: /root/.cache/pip/wheels/ee/33/44/0788a6e806866ae2e246d5cd841d07498a46bcb3f3c42ea5a4
# Successfully built query sqlalchemy
# ...

# %%
# Out:
# WARNING:When using a sequence of booleans for `ascending`, `na_position` flag is not yet supported and defaults to treating nulls as greater than all numbers
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-79-c04b6183b1b6> in <module>()
#       9       print("it is not applicable")
#      10       return df
# ---> 11 concatination(df)
#
# <ipython-input-79-c04b6183b1b6> in concatination(df, config)
#       4 def concatination(df, config=None):
#       5   for col in df.columns:
# ----> 6     if (col in ['ID','Loan.Lenght']) and (df[col].sort_values(df[col]>2000)):
#       7       return df[col].concat(axis=1)
#       8     else:
#
# /usr/local/lib/python3.6/site-packages/cudf/core/series.py in sort_values(self, ascending, na_position)
#    1503         if len(self) == 0:
#    1504             return self
# ...

# %%
import cudf
df=cudf.read_csv("/content/loan_data_test.csv")

config={"columns": ["ID"]}

def handle_missing_values(df, config):
    try:
        for col in config["columns"]:
            if (col not in ["columns"]) and (df[col].isnull().sum()>0):
                col_mean = df[col].mean()
                df[col] =  df[col].fillna(col_mean)
        df = df.dropna()
    except Exception as e:
        if(str(e) == "`mean` not supported with object series"):
            return df

    return df
handle_missing_values(df,config)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-12165e0ac83c> in <module>()
# ----> 1 import cudf
#       2 df=cudf.read_csv("/content/loan_data_test.csv")
#       3
#       4 config={"columns": ["ID"]}
#       5
#
# ModuleNotFoundError: No module named 'cudf'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
import cudf
df=cudf.read_csv("/content/loan_data_test.csv")

def find_all_indexes(df,search_str):
  try:
    for col in df.columns:
      col=df.index(search_str,0,1000000000)
      
  except ValueError as ve:
    if(str(ve) == "raised valueError"):
      return df

  return df

# %%
def pd_to_csv(df,config):
	return df.from_pandas(df)

# %%
def encode(df,config=None):
   return df.one_hot_encoding('ID', prefix='ID_', cats=[0, 1, 2])
  
encode(df)
# Out:
#         ID Amount.Requested Amount.Funded.By.Investors  ... ID__0 ID__1 ID__2
# 0    20093             5000                       5000  ...   0.0   0.0   0.0
# 1    62445            18000                      18000  ...   0.0   0.0   0.0
# 2    65248             7200                       7200  ...   0.0   0.0   0.0
# 3    81822             7200                       7200  ...   0.0   0.0   0.0
# 4    57923            22000                      22000  ...   0.0   0.0   0.0
# ..     ...              ...                        ...  ...   ...   ...   ...
# 295  24675            12000                      11975  ...   0.0   0.0   0.0
# 296  69456             5000                       5000  ...   0.0   0.0   0.0
# 297  97954             4375                       4375  ...   0.0   0.0   0.0
# 298  36931            13600                      13600  ...   0.0   0.0   0.0
# 299  34744             6000                       6000  ...   0.0   0.0   0.0
#
# [300 rows x 17 columns]

# %%
import cudf
import numpy as np

df=cudf.read_csv("/content/loan_data_test.csv")

config={"columns": ["Amount.Requested","Debt.To.Income.Ratio"] }
def convert_dtype(df,config):
  for cols in config["columns"]:
    df[cols] = df[cols].astype(np.float64)
    return df
df.dtypes
convert_dtype(df,config)
# Out:
#         ID  Amount.Requested  ... Inquiries.in.the.Last.6.Months Employment.Length
# 0    20093            5000.0  ...                              0          < 1 year
# 1    62445           18000.0  ...                              0         10+ years
# 2    65248            7200.0  ...                              0           6 years
# 3    81822            7200.0  ...                              0         10+ years
# 4    57923           22000.0  ...                              0           8 years
# ..     ...               ...  ...                            ...               ...
# 295  24675           12000.0  ...                              2           7 years
# 296  69456            5000.0  ...                              0         10+ years
# 297  97954            4375.0  ...                              2           6 years
# 298  36931           13600.0  ...                              0         10+ years
# ...

# %%
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
set(stopwords.words('english'))
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# {'a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  'her',
#  'here',
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  'if',
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'just',
#  'll',
# ...

# %%
import cudf
import io 
import nltk
from nltk.corpus import stopwords 
from nltk.tokenize import word_tokenize 
#word_tokenize accepts a string as an input, not a file. 
stop_words = set(stopwords.words('english')) 
df=cudf.read_csv("/content/loan_data_test.csv")
config={"columns":["Loan.Purpose"]}
def stop_words(df,config):
  for r in config["columns"]: 
    if r not in stop_words:
      filtered_sentence.append(r)
      return df  
        
stop_words(df,config)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-25-a53e1d090eb0> in <module>()
#      14       return df
#      15
# ---> 16 stop_words(df,config)
#
# <ipython-input-25-a53e1d090eb0> in stop_words(df, config)
#      10 def stop_words(df,config):
#      11   for r in config["columns"]:
# ---> 12     if r not in stop_words:
#      13       filtered_sentence.append(r)
#      14       return df
#
# TypeError: argument of type 'function' is not iterable

# %%
from sklearn.preprocessing import Binarizer 
import cudf 
import numpy 
df = cudf.read_csv("/content/loan_data_test.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-490e9a9785ce> in <module>()
#       3 import numpy
#       4 df = cudf.read_csv("/content/loan_data_test.csv")
# ----> 5 X = array[:,0:8]
#       6 Y = array[:,8]
#       7 binarizer = Binarizer(threshold=0.0).fit(X)
#
# NameError: name 'array' is not defined

# %%
import pandas as pd
import cudf as ddf

df=pd.read_csv("/content/loan_data_test.csv")
gdf=ddf.from_pandas(df)
gdf
# Out:
#         ID  Amount.Requested  ... Inquiries.in.the.Last.6.Months Employment.Length
# 0    20093              5000  ...                              0          < 1 year
# 1    62445             18000  ...                              0         10+ years
# 2    65248              7200  ...                              0           6 years
# 3    81822              7200  ...                              0         10+ years
# 4    57923             22000  ...                              0           8 years
# ..     ...               ...  ...                            ...               ...
# 295  24675             12000  ...                              2           7 years
# 296  69456              5000  ...                              0         10+ years
# 297  97954              4375  ...                              2           6 years
# 298  36931             13600  ...                              0         10+ years
# ...

# %%
df = cudf.DataFrame({'a': [0, 1, 2, 3],'b': [0.1, 0.2, None, 0.3]})
df
# Out:
#    a     b
# 0  0   0.1
# 1  1   0.2
# 2  2  null
# 3  3   0.3

# %%
import cudf
df=cudf.read_csv("/content/loan_data_test.csv")
config={"columns": ["Amount.Requested","Debt.To.Income.Ratio"] }
def drop_columns(df, config):
    return df.drop(config["columns"], axis=1)
drop_columns(df,config)
# Out:
#         ID  ... Employment.Length
# 0    20093  ...          < 1 year
# 1    62445  ...         10+ years
# 2    65248  ...           6 years
# 3    81822  ...         10+ years
# 4    57923  ...           8 years
# ..     ...  ...               ...
# 295  24675  ...           7 years
# 296  69456  ...         10+ years
# 297  97954  ...           6 years
# 298  36931  ...         10+ years
# 299  34744  ...           2 years
#
# [300 rows x 12 columns]

# %%
import cudf
df=cudf.read_csv("/content/loan_data_test.csv")
config={"columns": ["Amount.Requested","Amount.Funded.By.Investors"] }
def add_columns(df,config):
  for col in df.columns:
    add_column(self, name, data, forceindex=False)
    return df
add_columns(df,config)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-37-8f7eb3f09fb5> in <module>()
#       6     add_column(self, name, data, forceindex=False)
#       7     return df
# ----> 8 add_columns(df,config)
#
# <ipython-input-37-8f7eb3f09fb5> in add_columns(df, config)
#       4 def add_columns(df,config):
#       5   for col in df.columns:
# ----> 6     add_column(self, name, data, forceindex=False)
#       7     return df
#       8 add_columns(df,config)
#
# NameError: name 'add_column' is not defined

# %%
import cudf

df=cudf.read_csv('/content/loan_data_test.csv')
def missing_value(df):
	try:
    for col in df.columns:
      if(col not in ['ID']) and (df[col].isnull().sum()>0):
			col_mean = df[col].mean()
			df[col]=df[col].fillna(col_mean)
	except Exception as e:
		if(str(e)=="'mean' not supported"
			return df
	return df
# Out:
#   File "<ipython-input-9-76b6955a5624>", line 6
#     for col in df.columns:
#                           ^
# IndentationError: unindent does not match any outer indentation level

# %%
def handle_missing_values(df, config=None):
    try:
        for col in df.columns:
            if (col not in ['Interest.Rate', 'ID']) and (df[col].isnull().sum()>0):
                col_mean = df[col].mean()
                df[col] =  df[col].fillna(col_mean)
        df = df.dropna()
    except Exception as e:
        if(str(e) == "`mean` not supported with object series"):
            return df

    return df
handle_missing_values(df)
# Out:
#         ID Amount.Requested  ... Inquiries.in.the.Last.6.Months Employment.Length
# 0    20093             5000  ...                              0          < 1 year
# 1    62445            18000  ...                              0         10+ years
# 2    65248             7200  ...                              0           6 years
# 3    81822             7200  ...                              0         10+ years
# 4    57923            22000  ...                              0           8 years
# ..     ...              ...  ...                            ...               ...
# 295  24675            12000  ...                              2           7 years
# 296  69456             5000  ...                              0         10+ years
# 297  97954             4375  ...                              2           6 years
# 298  36931            13600  ...                              0         10+ years
# ...

# %%
import numpy as np 
def concatination(df, config=None):
  for col in df.columns:
    if (col in ['ID','Loan.Lenght']) and (df[col].sort_values(df[col]>2000)):
      return df[col].concat(axis=1)
    else:
      print("it is not applicable")
      return df

# %%
import numpy as np
def merge_col(df,config=None):
  for col in df.columns:
    df[col]=df[col].merge('ID','Loan.Lenght')
    return df
merge_col(df)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-46-18039572cf7b> in <module>()
#       4     df[col]=df[col].merge('ID','Loan.Lenght')
#       5     return df
# ----> 6 merge_col(df)
#
# <ipython-input-46-18039572cf7b> in merge_col(df, config)
#       2 def merge_col(df,config=None):
#       3   for col in df.columns:
# ----> 4     df[col]=df[col].merge('ID','Loan.Lenght')
#       5     return df
#       6 merge_col(df)
#
# AttributeError: 'Series' object has no attribute 'merge'

# %%
{"columns": ["Amount.Requested","Interest.Rate","Debt.To.Income.Ratio"] }
def aggregation(df,config):
  agg = df.groupby(["columns"]).sum().to_pandas()
  return agg
aggregation(df)
# Out:
#                          Monthly.Income  Inquiries.in.the.Last.6.Months
# ID     Amount.Requested
# 476    10000                    4133.33                               2
# 840    15600                   15000.00                               3
# 928    10000                    6666.67                               0
# 1046   5000                     4833.00                               0
# 1076   6500                     3333.00                               5
# ...                                 ...                             ...
# 102294 20000                    6916.67                               0
# 102580 3500                     3750.00                               4
# 102756 6700                     4700.00                               9
# 102775 6000                     4166.67                               1
# 103426 5500                     3937.08                               8
#
# [300 rows x 2 columns]

# %%
def encode(df,config=None):
  result = df.one_hot_encoding('ID', prefix='ID_', cats=[0, 1, 2])
  return result
encode(df)
# Out:
#         ID Amount.Requested Amount.Funded.By.Investors  ... ID__0 ID__1 ID__2
# 0    20093             5000                       5000  ...   0.0   0.0   0.0
# 1    62445            18000                      18000  ...   0.0   0.0   0.0
# 2    65248             7200                       7200  ...   0.0   0.0   0.0
# 3    81822             7200                       7200  ...   0.0   0.0   0.0
# 4    57923            22000                      22000  ...   0.0   0.0   0.0
# ..     ...              ...                        ...  ...   ...   ...   ...
# 295  24675            12000                      11975  ...   0.0   0.0   0.0
# 296  69456             5000                       5000  ...   0.0   0.0   0.0
# 297  97954             4375                       4375  ...   0.0   0.0   0.0
# 298  36931            13600                      13600  ...   0.0   0.0   0.0
# 299  34744             6000                       6000  ...   0.0   0.0   0.0
#
# [300 rows x 17 columns]

# %%
def counts_val(df,config=None):
  df = df['ID'].value_counts()
  return df
counts_val(df)
# Out:
# 476       1
# 840       1
# 928       1
# 1046      1
# 1076      1
#          ..
# 102294    1
# 102580    1
# 102756    1
# 102775    1
# 103426    1
# Name: ID, Length: 300, dtype: int32

# %%
def asc(df,config=None):
  df=df.sort_values('ID', ascending=False)
  return df
asc(df)
# Out:
#          ID Amount.Requested  ... Inquiries.in.the.Last.6.Months Employment.Length
# 208  103426             5500  ...                              8         10+ years
# 140  102775             6000  ...                              1           2 years
# 22   102756             6700  ...                              9           2 years
# 47   102580             3500  ...                              4         10+ years
# 90   102294            20000  ...                              0         10+ years
# ..      ...              ...  ...                            ...               ...
# 85     1076             6500  ...                              5         10+ years
# 103    1046             5000  ...                              0           4 years
# 212     928            10000  ...                              0           4 years
# 251     840            15600  ...                              3           2 years
# ...

# %%
import cudf
df=cudf.read_csv("/content/loan_data_test.csv")
def num_missing(x):
  return sum(x.isnull())
print ("Missing values per column:")
df['ID'].applymap(num_missing)
# Out:
# Missing values per column:
# ---------------------------------------------------------------------------
# TypingError                               Traceback (most recent call last)
# <ipython-input-6-efd447523f19> in <module>()
#       4   return sum(x.isnull())
#       5 print ("Missing values per column:")
# ----> 6 df['ID'].applymap(num_missing)
#
# /usr/local/lib/python3.6/site-packages/cudf/core/series.py in applymap(self, udf, out_dtype)
#    1748         """
#    1749         if callable(udf):
# -> 1750             res_col = self._unaryop(udf)
#    1751         else:
#    1752             res_col = self._column.applymap(udf, out_dtype=out_dtype)
#
# /usr/local/lib/python3.6/site-packages/cudf/core/series.py in _unaryop(self, fn)
#     618         operand.
#     619         """
# --> 620         outcol = self._column.unary_operator(fn)
#     621         return self._copy_construct(data=outcol)
#     622
#
# ...

# %%
from numba import cuda

@cuda.jit
def multiply(df,config=None):
    i = cuda.grid(1)
    if i < df.size: # boundary guard
        df[i] = df[i] * multiplier
        return df
multiply(df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-67-965671fd8803> in <module>()
#       7         df[i] = df[i] * multiplier
#       8         return df
# ----> 9 multiply(df)
#
# /usr/local/lib/python3.6/site-packages/numba/cuda/compiler.py in __call__(self, *args)
#     797         Specialize and invoke this kernel with *args*.
#     798         '''
# --> 799         kernel = self.specialize(*args)
#     800         cfg = kernel[self.griddim, self.blockdim, self.stream, self.sharedmem]
#     801         cfg(*args)
#
# /usr/local/lib/python3.6/site-packages/numba/cuda/compiler.py in specialize(self, *args)
#     807         '''
#     808         argtypes = tuple(
# --> 809             [self.typingctx.resolve_argument_type(a) for a in args])
#     810         kernel = self.compile(argtypes)
#     811         return kernel
#
# ...

# %%
gdf=cudf.read_csv("/content/loan_data_test.csv")
def conditional_add(df):
    for i, (a, e) in enumerate(zip(df)):
        if a > 0:
            df[i] = a + e
        else:
            df[i] = a
            return df
gdf['ID'].applymap(conditional_add)
# Out:
# ---------------------------------------------------------------------------
# TypingError                               Traceback (most recent call last)
# <ipython-input-71-3ebfee8acf59> in <module>()
#       7             df[i] = a
#       8             return df
# ----> 9 gdf['ID'].applymap(conditional_add)
#
# /usr/local/lib/python3.6/site-packages/cudf/core/series.py in applymap(self, udf, out_dtype)
#    1748         """
#    1749         if callable(udf):
# -> 1750             res_col = self._unaryop(udf)
#    1751         else:
#    1752             res_col = self._column.applymap(udf, out_dtype=out_dtype)
#
# /usr/local/lib/python3.6/site-packages/cudf/core/series.py in _unaryop(self, fn)
#     618         operand.
#     619         """
# --> 620         outcol = self._column.unary_operator(fn)
#     621         return self._copy_construct(data=outcol)
#     622
#
# /usr/local/lib/python3.6/site-packages/cudf/core/column/numerical.py in unary_operator(self, unaryop)
# ...

# %%
def udf(x):
    if x > 0:
        return x + 5
    else:
        return x - 5
df['ID'].applymap(udf)
# Out:
# 0      20098
# 1      62450
# 2      65253
# 3      81827
# 4      57928
#        ...
# 295    24680
# 296    69461
# 297    97959
# 298    36936
# 299    34749
# Name: ID, Length: 300, dtype: int64

# %%
# only select certain columns (and overwrite the gdf)
column_names = [
    'ID','Loan.Length'
]
gdf = gdf.loc[:, column_names]

# show the first 5 records of each column
print(gdf.head(5))
# Out:
#       ID Loan.Length
# 0  20093   60 months
# 1  62445   60 months
# 2  65248   60 months
# 3  81822   36 months
# 4  57923   60 months

# %%
import numpy as np

# convert the following two int64 columns to float64 data type
gdf['ID'] = gdf['ID'].astype(np.float64)
gdf['Loan.Length'] = gdf['Loan.Length'].astype(np.float64)

# take another look
gdf.dtypes
gdf
# Out:
#           ID  Loan.Length
# 0    20093.0         60.0
# 1    62445.0         60.0
# 2    65248.0         60.0
# 3    81822.0         36.0
# 4    57923.0         60.0
# ..       ...          ...
# 295  24675.0         60.0
# 296  69456.0         36.0
# 297  97954.0         36.0
# 298  36931.0         60.0
# 299  34744.0         36.0
#
# [300 rows x 2 columns]

# %%
# so it more accurately represents income earned
gdf=cudf.read_csv("/content/loan_data_test.csv")
amount= gdf["Amount.Requested"][0]   # take constant from first row
print('adjustment factor: {}'.format(amount))
def adjust_income(income):
    return amount * income;

# apply it to the 'population' column
gdf['Monthly.Income'] = gdf['Monthly.Income'].applymap(adjust_income)

# drop the ADJUST column
gdf.drop_column('Amount.Requested')

# compute the mean
print('mean adjusted income: {}'.format(gdf['Monthly.Income'].mean()))
# Out:
# adjustment factor: 5000
# ---------------------------------------------------------------------------
# TypingError                               Traceback (most recent call last)
# <ipython-input-38-cf5636eb53f5> in <module>()
#       6
#       7 # apply it to the 'population' column
# ----> 8 gdf['Monthly.Income'] = gdf['Monthly.Income'].applymap(adjust_income)
#       9
#      10 # drop the ADJUST column
#
# /usr/local/lib/python3.6/site-packages/cudf/core/series.py in applymap(self, udf, out_dtype)
#    1748         """
#    1749         if callable(udf):
# -> 1750             res_col = self._unaryop(udf)
#    1751         else:
#    1752             res_col = self._column.applymap(udf, out_dtype=out_dtype)
#
# /usr/local/lib/python3.6/site-packages/cudf/core/series.py in _unaryop(self, fn)
#     618         operand.
#     619         """
# --> 620         outcol = self._column.unary_operator(fn)
#     621         return self._copy_construct(data=outcol)
#     622
#
# ...

# %%
gdf = gdf.sort_values(by='ID', ascending=True)
# reset the index so we can use loc slicing later
gdf = gdf.reset_index()
print(gdf.head(5))
# Out:
#    index    ID  ... Inquiries.in.the.Last.6.Months Employment.Length
# 0     40   476  ...                              2         10+ years
# 1    251   840  ...                              3           2 years
# 2    212   928  ...                              0           4 years
# 3    103  1046  ...                              0           4 years
# 4     85  1076  ...                              5         10+ years
#
# [5 rows x 15 columns]

# %%
# how many records do we have?
print("{} = Original # of records".format(len(gdf)))

# filter out
gdf = gdf.query('ID >= 1000')

# how many records do we have left?
print("{} = New # of records".format(len(gdf)))

# sanity check...
gdf
# Out:
# 297 = Original # of records
# 297 = New # of records
#      index      ID  ... Inquiries.in.the.Last.6.Months Employment.Length
# 3      103    1046  ...                              0           4 years
# 4       85    1076  ...                              5         10+ years
# 5      265    1336  ...                              1           8 years
# 6      123    1392  ...                              0           3 years
# 7      289    1494  ...                              0           3 years
# ..     ...     ...  ...                            ...               ...
# 295     90  102294  ...                              0         10+ years
# 296     47  102580  ...                              4         10+ years
# 297     22  102756  ...                              9           2 years
# 298    140  102775  ...                              1           2 years
# 299    208  103426  ...                              8         10+ years
#
# [297 rows x 15 columns]

# %%
# define the categorical columns
gdf=cudf.read_csv("/content/loan_data_test.csv")
cat_cols = set(['Loan.Purpose','Home.Ownership'])
# store the unique values for each category column
uniques = {}

# iterate through each categorical column and one-hot
# encode it using the unique values it has
for k in cat_cols:
    uniques[k] = gdf[k].unique_k(k=1000)
    cats = uniques[k][1:]  # drop first
    gdf = gdf.one_hot_encoding(k, prefix=k, cats=cats)
    del gdf[k]
    
# we should see many more columns since the categorical
# columns will get expanded due to one-hot encoding
gdf.dtypes
# Out:
# ID                                   int64
# Amount.Requested                    object
# Amount.Funded.By.Investors          object
# Loan.Length                         object
# Debt.To.Income.Ratio                object
# State                               object
# Monthly.Income                     float64
# FICO.Range                          object
# Open.CREDIT.Lines                   object
# Revolving.CREDIT.Balance            object
# Inquiries.in.the.Last.6.Months       int64
# Employment.Length                   object
# Loan.Purpose_credit_card           float64
# Loan.Purpose_debt_consolidation    float64
# Loan.Purpose_educational           float64
# Loan.Purpose_home_improvement      float64
# Loan.Purpose_house                 float64
# Loan.Purpose_major_purchase        float64
# Loan.Purpose_medical               float64
# Loan.Purpose_moving                float64
# Loan.Purpose_other                 float64
# Loan.Purpose_renewable_energy      float64
# ...

# %%
# enforce float64 data type on ALL columns
for k in gdf.columns:
    gdf[k] = gdf[k].astype(np.float64)

# set the fractions for training and validation
fractions = {
    "train": 0.8,
    "valid": 0.2
}

# validation splitpoint
splitpoint = int(len(gdf) * fractions["train"])
print('splitpoint: {} of {} is {}'.format(fractions["train"], len(gdf), splitpoint))

# break the gdf up into training and validation sets
gdfs = {
    "train": gdf.loc[:splitpoint],
    "valid": gdf.loc[splitpoint:]
}
print('gdfs["train"] has {} rows'.format(len(gdfs["train"])))
print('gdfs["valid"] has {} rows'.format(len(gdfs["valid"])))
# Out:
# splitpoint: 0.8 of 300 is 240
# gdfs["train"] has 241 rows
# gdfs["valid"] has 60 rows

# %%
# this step should not be necessary in the near future
# (should be able to use gdf as input)

matrices = {
    "train": {
        "x": gdfs["train"].as_gpu_matrix(columns=gdf.columns[1:]),
        "y": gdfs["train"].as_gpu_matrix(columns=[gdf.columns[0]])
    },
    "valid": {
        "x": gdfs["valid"].as_gpu_matrix(columns=gdf.columns[1:]),
        "y": gdfs["valid"].as_gpu_matrix(columns=[gdf.columns[0]])
    }
}

# check the matrix shapes (sanity check)
print('matrices["train"]["x"] shape:', matrices["train"]["x"].shape)
print('matrices["train"]["y"] shape:', matrices["train"]["y"].shape)
print('matrices["valid"]["x"] shape:', matrices["valid"]["x"].shape)
print('matrices["valid"]["y"] shape:', matrices["valid"]["y"].shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-51-36add70a7b77> in <module>()
#       2 matrices = {
#       3     "train": {
# ----> 4         "x": gdfs["train"].as_gpu_matrix(columns=gdf.columns[1:].fillna(Employment.Lenght)),
#       5         "y": gdfs["train"].as_gpu_matrix(columns=[gdf.columns[0]])
#       6     },
#
# NameError: name 'Employment' is not defined

# %%
df=cudf.read_csv('loan_data_test.csv')
def calculate_stat(df):
  return df.describe()
calculate_stat(df)
# Out:
#                   ID  Monthly.Income  Inquiries.in.the.Last.6.Months
# count     300.000000      300.000000                      300.000000
# mean    48851.100000     5413.314367                        0.966667
# std     28668.362929     3030.583707                        1.315799
# min       476.000000     1000.000000                        0.000000
# 25%     27548.750000     3595.832500                        0.000000
# 50%     45611.000000     4816.500000                        1.000000
# 75%     72110.500000     6399.250000                        2.000000
# max    103426.000000    21666.670000                        9.000000

# %%
df=cudf.read_csv("/content/loan_data_test.csv")

def multi(num):
	return num * 4
df['ID'].applymap(multi)
# Out:
# 0       80372
# 1      249780
# 2      260992
# 3      327288
# 4      231692
#         ...
# 295     98700
# 296    277824
# 297    391816
# 298    147724
# 299    138976
# Name: ID, Length: 300, dtype: int64

# %%
import cudf
df=cudf.read_csv('/content/loan_data_test.csv')
def drop_columns(df):
    return df.drop(['ID'], axis=1)
drop_columns(df)
# Out:
#     Amount.Requested  ... Employment.Length
# 0               5000  ...          < 1 year
# 1              18000  ...         10+ years
# 2               7200  ...           6 years
# 3               7200  ...         10+ years
# 4              22000  ...           8 years
# ..               ...  ...               ...
# 295            12000  ...           7 years
# 296             5000  ...         10+ years
# 297             4375  ...           6 years
# 298            13600  ...         10+ years
# 299             6000  ...           2 years
#
# [300 rows x 13 columns]

# %%
def select_col(df):
  return df.loc[1: ,['ID','State']]
select_col(df)
# Out:
#         ID State
# 1    62445    CA
# 2    65248    LA
# 3    81822    NY
# 4    57923    MI
# 5    33777    NJ
# ..     ...   ...
# 295  24675    NV
# 296  69456    CA
# 297  97954    CA
# 298  36931    MN
# 299  34744    IL
#
# [299 rows x 2 columns]

# %%
def index(df):
  if df[df.ID<9000]:
    return df.loc[1:90,['ID','State']]
  else:
    return 0
index(df)
# Out:
#         ID State
# 1    62445    CA
# 2    65248    LA
# 3    81822    NY
# 4    57923    MI
# 5    33777    NJ
# ..     ...   ...
# 86   34051    CA
# 87   61906    NC
# 88   19069    RI
# 89   35025    CA
# 90  102294    MN
#
# [90 rows x 2 columns]

# %%
@jit(nopython=True)
def apply_operation(num):
  if num<0:
      return num + 10
  elif num>=100:
      return num - 50


df['ID'].applymap(apply_operation)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-37-c7738b9404e3> in <module>()
# ----> 1 @jit(nopython=True)
#       2 def apply_operation(num):
#       3   if num<0:
#       4       return num + 10
#       5   elif num>=100:
#
# NameError: name 'jit' is not defined

# %%
def cols_to_numeric(df):
    for col in df['ID']:
#         pd.to_numeric(df[col],errors='coerce')
        df[col]=df[col].map(lambda x: pd.to_numeric(x, errors='coerce'))
    return df
cols_to_numeric(df)
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-47-8819f3b97e4e> in <module>()
#       5         df[col]=df[col].map(lambda x: pd.to_numeric(x, errors='coerce'))
#       6     return df
# ----> 7 cols_to_numeric(df.ID)
#
# <ipython-input-47-8819f3b97e4e> in cols_to_numeric(df)
#       1
#       2 def cols_to_numeric(df):
# ----> 3     for col in df['ID']:
#       4 #         pd.to_numeric(df[col],errors='coerce')
#       5         df[col]=df[col].map(lambda x: pd.to_numeric(x, errors='coerce'))
#
# /usr/local/lib/python3.6/site-packages/cudf/core/series.py in __getitem__(self, arg)
#     427
#     428     def __getitem__(self, arg):
# --> 429         data = self._column[arg]
#     430         index = self.index.take(arg)
#     431         if is_scalar(data) or data is None:
#
# ...

# %%
json_file_path = "/content/config.json"

with open(json_file_path, 'r') as j:
     contents = json.loads(j.read())
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-53-f287f215d7a7> in <module>()
#       2
#       3 with open(json_file_path, 'r') as j:
# ----> 4      contents = json.loads(j.read())
#
# /usr/lib/python3.6/json/__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     352             parse_int is None and parse_float is None and
#     353             parse_constant is None and object_pairs_hook is None and not kw):
# --> 354         return _default_decoder.decode(s)
#     355     if cls is None:
#     356         cls = JSONDecoder
#
# /usr/lib/python3.6/json/decoder.py in decode(self, s, _w)
#     337
#     338         """
# --> 339         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     340         end = _w(s, end).end()
#     341         if end != len(s):
#
# ...
